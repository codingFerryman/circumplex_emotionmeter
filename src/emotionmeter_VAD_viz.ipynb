# %%
# Load packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load results
result_anew_path = '../output_anew.csv'
anew_df = pd.read_csv(result_anew_path)
result_nrc_path = '../output_nrc.csv'
nrc_df = pd.read_csv(result_nrc_path)
result_trump = '../output_trump_anew.csv'
trump_df = pd.read_csv(result_trump)
result_trump_nrc = '../output_trump_nrc.csv'
trump_df_nrc = pd.read_csv(result_trump_nrc)

# %%
trump_df_nrc[['valence', 'arousal', 'dominance']].hist(bins=12, figsize=(15,5), layout=(1,3))
plt.tight_layout()
plt.show()

# %%
trump_df[['valence', 'arousal', 'dominance']].hist(bins=12, figsize=(15,5), layout=(1,3))
plt.tight_layout()
plt.show()

# %%
anew_df[['valence', 'arousal', 'dominance']].hist(bins=12, figsize=(15,5), layout=(1,3))
plt.tight_layout()
plt.show()

# %%
nrc_df[['valence', 'arousal', 'dominance']].hist(bins=15, figsize=(15,5), layout=(1,3))
plt.tight_layout()
plt.show()

# %%
anew_df
# Out:
#             Party         Handle  \
# 0        Democrat  RepDarrenSoto
# 1        Democrat  RepDarrenSoto
# 2        Democrat  RepDarrenSoto
# 3        Democrat  RepDarrenSoto
# 4        Democrat  RepDarrenSoto
# ...           ...            ...
# 85700  Republican    RepTomPrice
# 85701  Republican    RepTomPrice
# 85702  Republican    RepTomPrice
# 85703  Republican    RepTomPrice
# 85704  Republican    RepTomPrice
#
#                                                    Tweet   valence   arousal  \
# 0      Today, Senate Dems vote to #SaveTheInternet. P...  0.570815  0.012346
# 1      RT @WinterHavenSun: Winter Haven resident / Al...  0.253731 -0.322034
# 2      RT @NBCLatino: .@RepDarrenSoto noted that Hurr...  0.000000  0.000000
# 3      RT @NALCABPolicy: Meeting with @RepDarrenSoto ...  0.345336 -0.126638
# 4      RT @Vegalteno: Hurricane season starts on June...  0.000000  0.000000
# ...                                                  ...       ...       ...
# ...

# %%
print("Highest positive valence")
anew_df.sort_values('valence', ascending=False)[:3]
# Out:
# Highest positive valence
#             Party           Handle  \
# 6657     Democrat   StaceyPlaskett
# 66872  Republican      RepHartzler
# 47660  Republican  RepTomMacArthur
#
#                                                    Tweet   valence   arousal  \
# 6657   RT @RepBonnie: So thankful for your kind birth...  0.860724  0.550173
# 66872  Happy Mother’s Day! I’m so grateful for my mot...  0.854334  0.630435
# 47660  Merry Christmas! May the spirit of Christmas f...  0.854281  0.413379
#
#        dominance
# 6657    0.686766
# 66872   0.702602
# 47660   0.664992

# %%
print("Highest negative valence")
anew_df.sort_values('valence', ascending=True)[:3]
# Out:
# Highest negative valence
#             Party        Handle  \
# 2849     Democrat      RepJoshG
# 41019    Democrat  RepMikeHonda
# 72941  Republican   JudgeTedPoe
#
#                                                    Tweet   valence   arousal  \
# 2849   Lung Cancer is the second-leading cause of dea... -0.792815  0.320885
# 41019  Rape is rape. And rape is wrong. https://t.co/... -0.769053  0.540827
# 72941  RT @lindsayaellis: Nancy Downing at TAMU bring... -0.747793  0.679744
#
#        dominance
# 2849   -0.698795
# 41019  -0.660729
# 72941  -0.616858

# %%
print("Highest positive arousal")
anew_df.sort_values('arousal', ascending=False)[:3]
# Out:
# Highest positive arousal
#             Party           Handle  \
# 24657    Democrat  RepBrendanBoyle
# 82688  Republican      RepPeteKing
# 80170  Republican     RepPeteOlson
#
#                                                    Tweet   valence   arousal  \
# 24657  The last 24 hours in Philly sports: Flyers win...  0.784134  0.737533
# 82688  .@NotreDame Women's Basketball Team win NCAA C...  0.779614  0.712023
# 80170  Wishing a happy 70th birthday to the @USAFRese...  0.688651  0.709091
#
#        dominance
# 24657   0.696279
# 82688   0.511002
# 80170   0.589744

# %%
print("Highest negative arousal")
anew_df.sort_values('arousal', ascending=True)[:3]
# Out:
# Highest negative arousal
#             Party         Handle  \
# 1253     Democrat   RepTomSuozzi
# 67385  Republican  RepBillFlores
# 73133  Republican      DrPhilRoe
#
#                                                    Tweet   valence   arousal  \
# 1253   The residents of Queens &amp; LI deserve to li...  0.492386 -0.615754
# 67385  RT @SpeakerRyan: We are just 5 days away from ... -0.488196 -0.609259
# 73133  Workers deserve a secure and stable retirement...  0.526627 -0.606299
#
#        dominance
# 1253   -0.137597
# 67385  -0.438034
# 73133   0.302288

# %%
print("Highest valence x arousal")
anew_df.iloc[(anew_df['valence']*anew_df['arousal']).sort_values(ascending=False)[:3].index]
# Out:
# Highest valence x arousal
#             Party           Handle  \
# 42734  Republican      RepJimBanks
# 24657    Democrat  RepBrendanBoyle
# 41731    Democrat     keithellison
#
#                                                    Tweet   valence   arousal  \
# 42734  Happy 60th birthday to my mom! Like most mothe...  0.827064  0.702381
# 24657  The last 24 hours in Philly sports: Flyers win...  0.784134  0.737533
# 41731  RT @Jacob_Frey: No city does #MayDay like MPLS...  0.813171  0.696049
#
#        dominance
# 42734   0.544419
# 24657   0.696279
# 41731   0.655469

# %%
print("Lowest valence x arousal")
anew_df.iloc[(anew_df['valence']*anew_df['arousal']).sort_values(ascending=True)[:3].index]
# Out:
# Lowest valence x arousal
#             Party          Handle  \
# 72941  Republican     JudgeTedPoe
# 65808  Republican   RepJeffDuncan
# 64122  Republican  HerreraBeutler
#
#                                                    Tweet   valence   arousal  \
# 72941  RT @lindsayaellis: Nancy Downing at TAMU bring... -0.747793  0.679744
# 65808  If police pick up an illegal alien &amp; alleg... -0.671705  0.703484
# 64122  I’m pleased we were able to secure a 2-year fu...  0.757429 -0.577998
#
#        dominance
# 72941  -0.616858
# 65808  -0.682891
# 64122   0.628598

# %% [markdown]
# ## Parties

# %%
party_anew_df = anew_df[['Party', 'valence', 'arousal', 'dominance']]
party_nrc_df = nrc_df[['Party', 'valence', 'arousal', 'dominance']]

# %%
party_anew_df.groupby('Party').mean()
# Out:
#              valence   arousal  dominance
# Party
# Democrat    0.254750  0.079982   0.163882
# Republican  0.278132  0.052083   0.175970

# %%
party_nrc_df.groupby('Party').mean()
# Out:
#              valence   arousal  dominance
# Party
# Democrat    0.435572 -0.119120   0.361390
# Republican  0.482882 -0.159358   0.375422

# %%
fig, axs = plt.subplots(1, 3, figsize=(24, 8))
axs = axs.ravel()

sns.boxplot(x='Party', y='valence', data=party_anew_df, ax=axs[0])
axs[0].set_title('Valence')

sns.boxplot(x='Party', y='arousal', data=party_anew_df, ax=axs[1])
axs[1].set_title('Arousal')

sns.boxplot(x='Party', y='dominance', data=party_anew_df, ax=axs[2])
axs[2].set_title('Dominance')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(24, 8))
axs = axs.ravel()

sns.boxplot(x='Party', y='valence', data=party_nrc_df, ax=axs[0])
axs[0].set_title('Valence')

sns.boxplot(x='Party', y='arousal', data=party_nrc_df, ax=axs[1])
axs[1].set_title('Arousal')

sns.boxplot(x='Party', y='dominance', data=party_nrc_df, ax=axs[2])
axs[2].set_title('Dominance')

plt.show()

# %% [markdown]
# ## Handles

# %%
democrat_df = anew_df[anew_df.Party=='Democrat'][['Handle', 'valence', 'arousal']]

# %%
democrat_handle = democrat_df.groupby('Handle').mean()
democrat_handle
# Out:
#                   valence   arousal
# Handle
# AGBecerra        0.223490  0.073324
# AlanGrayson      0.256687  0.108436
# AnthonyBrownMD4  0.290448  0.110458
# BennieGThompson  0.226698  0.013455
# BettyMcCollum04  0.252244  0.068886
# ...                   ...       ...
# repjohnlewis     0.231683  0.092220
# repmarkpocan     0.265879  0.046514
# repsandylevin    0.106372 -0.038067
# rosadelauro      0.269841  0.090594
# sethmoulton      0.260752  0.117576
#
# [211 rows x 2 columns]

# %%
republican_df = anew_df[anew_df.Party=='Republican'][['Handle', 'valence', 'arousal']]

# %%
republican_handle = republican_df.groupby('Handle').mean()
republican_handle
# Out:
#                   valence   arousal
# Handle
# AustinScottGA08  0.329409  0.058621
# ConawayTX11      0.309676  0.045847
# CongCulberson    0.256612  0.112237
# CongMikeSimpson  0.353913  0.107160
# CongressmanDan   0.317502  0.064005
# ...                   ...       ...
# repdonyoung      0.370935  0.085745
# repgregwalden    0.315058  0.050427
# replouiegohmert  0.272751  0.028334
# reppittenger     0.236054  0.059917
# virginiafoxx     0.379669  0.122141
#
# [222 rows x 2 columns]

# %% [markdown]
# ## Hashtag (TBD)

# %%
# This function only returns NULL values now. Debuging ...
"""
Reference: https://github.com/elliottash/emotionmeter/blob/c75ae44974d476e10bdef59128bb2867a77f197b/emotionmeter.py#L180
"""
def calc_hashtags_odd_ratio_for_party(df, col_name: str, party: str, ascending=False):
    df = df[(df['language'] == 'en') & (df['token'] > 4)].sort_values(col_name, ascending=ascending)
    den = len(df['hashtags'])

    if "Party" not in df.columns:
        raise Exception("df must have column Party!")
    if party not in df["Party"].unique():
        raise Exception("this party", party, "is not in the column Party!")

    filtered_df = df[(df['language'] == 'en') & (df['token'] > 4) & (df['Party'] == party)].sort_values(col_name, ascending=ascending)
    den_filtered = len(filtered_df["hashtags"])

    odd_ratio = []
    hashtags = [str(hashtag) for hashtag in list(df["hashtags"]) if str(hashtag).strip() != ""]

    # compute the odd-ratio for this party with positive:negative ratios against other types of hashtags
    for hashtag in hashtags:
        num = (1 + sum(pd.Series(df['hashtags']).str.contains(hashtag)))
        num_filtered = (1 + sum(pd.Series(filtered_df['hashtags']).str.contains(hashtag)))
        try:
            p = num_filtered / den_filtered
            q = (num - num_filtered) / (den - den_filtered)
            odd_ratio.append((p / (1 - p)) / (q / (1 - q)))
        except:
            odd_ratio.append(-1)

    return pd.DataFrame({"hashtag": hashtags, f"{col_name}_odd_ratio": odd_ratio}).sort_values( f"{col_name}_odd_ratio", ascending=ascending)

# %%
hashtags_df = anew_df[['Party', 'hashtags']]

# %%
hashtags_de = hashtags_df[hashtags_df['Party']=='Republican']['hashtags'].dropna()

# %%
h_de = []
for w in hashtags_de.tolist():
    _w_l = w.split(',')
    for _ww in _w_l:
        h_de.append(_ww.rstrip())

# %%
from collections import Counter

# %%
Counter(h_de).most_common()
# Out:
# [('#TaxReform', 508),
#  ('#TaxCutsandJobsAct', 465),
#  ('#taxreform', 306),
#  ('#SOTU', 245),
#  ('#TaxDay', 167),
#  ('#SmallBusinessWeek', 144),
#  ('#2018FarmBill', 117),
#  ('#TaxCutsAndJobsAct', 104),
#  ('#FullCmte', 99),
#  ('#SchumerShutdown', 96),
#  ('#FY19NDAA', 96),
#  ('#SNAP', 92),
#  ('#SubHealth', 85),
#  ('#AskBuddy', 77),
#  ('#FarmBill', 70),
#  ('#VA05', 70),
#  ('#TaxCutsandJobsAct.', 68),
#  ('#GOPFuture', 68),
#  ('#OnThisDay', 66),
#  ('#FOSTA', 66),
#  ('#NDAA', 65),
#  ('#sayfie', 63),
#  ('#DACA', 63),
#  ('#OpioidCrisis', 61),
#  ('#TaxReform.', 59),
#  ('#ICYMI', 58),
#  ('#CA08', 57),
#  ('#NationalPoliceWeek', 56),
#  ('#Obamacare', 54),
#  ('#SmallBiz', 52),
#  ('#124;', 52),
#  ('#utpol', 51),
#  ('#SouthJersey', 51),
#  ('#OTD', 48),
#  ('#opioidcrisis', 47),
#  ('#NationalAgDay', 47),
#  ('#MN02', 46),
#  ('#smallbiz', 46),
#  ('#BetterWay', 46),
#  ('#AL03', 45),
#  ('#FY18NDAA', 44),
#  ('#infrastructure', 43),
#  ('#HASC', 42),
# ...

# %% [markdown]
# ## Corr

# %%
lexicons_df = anew_df[['valence', 'arousal', 'dominance']].join(nrc_df[['valence', 'arousal', 'dominance']], lsuffix='_anew', rsuffix='_nrc')

# %%
lexicons_df.corr('spearman')
# Out:
#                 valence_anew  arousal_anew  dominance_anew  valence_nrc  \
# valence_anew        1.000000      0.334375        0.880324     0.666494
# arousal_anew        0.334375      1.000000        0.294820     0.193778
# dominance_anew      0.880324      0.294820        1.000000     0.584070
# valence_nrc         0.666494      0.193778        0.584070     1.000000
# arousal_nrc        -0.045060      0.424645       -0.009909    -0.124534
# dominance_nrc       0.329732      0.284259        0.318606     0.515956
#
#                 arousal_nrc  dominance_nrc
# valence_anew      -0.045060       0.329732
# arousal_anew       0.424645       0.284259
# dominance_anew    -0.009909       0.318606
# valence_nrc       -0.124534       0.515956
# arousal_nrc        1.000000       0.333796
# dominance_nrc      0.333796       1.000000
